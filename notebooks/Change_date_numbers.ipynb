# %%
import pandas as pd
import numpy as np

df = pd.read_csv("data/thesis_comp_ingelec_quimica_head.csv")
df
# Out:
#     index  thesis_year                                       thesis_title  \
# 0      59   3-Jun-2011  Análisis del comportamiento de mezclas de PP c...
# 1    1610  18-Feb-2013  Caracterización y preparación de parafinas par...
# 2    1660  27-Feb-2013  Influencia del soporte de la reacción de hidro...
# 3    3095  23-Apr-2015  Síntesis y caracterízación de nuevos materiale...
# 4    3084  22-Apr-2015  Aislamiento y caracterización de los principio...
# ..    ...          ...                                                ...
# 85   5633  18-Apr-2017  Prototipo de un archivo de documentos digitale...
# 86   5728  25-May-2017  Diseño y desarrollo de un módulo de comunicaci...
# 87   5727  25-May-2017  Gestor de objetos de aprendizaje de contenidos...
# 88   5725  25-May-2017  Implantación de una plataforma de software col...
# 89   5726  25-May-2017  Implementación de un sistema de recomendación ...
#
#                                thesis_author     size  \
# ...

# %%
df['thesis_year'] = pd.to_datetime(df['thesis_year'])
df
# Out:
#     index thesis_year                                       thesis_title  \
# 0      59  2011-06-03  Análisis del comportamiento de mezclas de PP c...
# 1    1610  2013-02-18  Caracterización y preparación de parafinas par...
# 2    1660  2013-02-27  Influencia del soporte de la reacción de hidro...
# 3    3095  2015-04-23  Síntesis y caracterízación de nuevos materiale...
# 4    3084  2015-04-22  Aislamiento y caracterización de los principio...
# ..    ...         ...                                                ...
# 85   5633  2017-04-18  Prototipo de un archivo de documentos digitale...
# 86   5728  2017-05-25  Diseño y desarrollo de un módulo de comunicaci...
# 87   5727  2017-05-25  Gestor de objetos de aprendizaje de contenidos...
# 88   5725  2017-05-25  Implantación de una plataforma de software col...
# 89   5726  2017-05-25  Implementación de un sistema de recomendación ...
#
#                                thesis_author     size  \
# ...

# %%
df.to_csv("data/thesis_comp_ingelec_quimica_date_head.csv")

# %%
df_tutor = pd.read_csv("./data/thesis_tutor_7078_clean_v2.csv")
df_tutor
# Out:
#       index  thesis_year                                       thesis_title  \
# 0         1         2009  Estudio de sobretensiones por maniobra debido ...
# 1        95  20-Jun-2011  Estudio de la influencia de las condiciones de...
# 2        22  31-May-2011  Efecto de los rayos gamma (g) sobre el comport...
# 3        24  31-May-2011  Determinación de registros pseudo sónicos a pa...
# 4        25  31-May-2011  Propuesta de un sistema de administración de i...
# ...     ...          ...                                                ...
# 7073   8190  12-Nov-2020  Magnitud y estructura del abastecimiento exter...
# 7074   8192  12-Nov-2020  Evaluación del Impacto de Cambios de Cobertura...
# 7075   8193  18-Nov-2020  Efecto de la sombra sobre la concentración de ...
# 7076   8196  18-Nov-2020  Evaluación del comportamiento ecofisiológico d...
# 7077   8211  12-Mar-2021  La industria musical surcoreana, recepción y a...
#
# ...

# %%
franky_thesis = df_tutor[df_tutor["thesis_tutor"]=="Franky Uzcategui"].tail(5)
franky_thesis
# Out:
#       index  thesis_year                                       thesis_title  \
# 6426   7509  26-Feb-2019  Desarrollo de un sistema de gestión de proceso...
# 6432   7514   6-Mar-2019  Desarrollo de una solución de inteligencia de ...
# 6914   8039  14-Jan-2020  Desarrollo de modelo de arquitectura orientada...
# 6922   8035  14-Jan-2020  desarrollo de una solución de inteligencia de ...
# 6925   8038  14-Jan-2020  Desarrollo de una solución de inteligencia de ...
#
#                                           thesis_author     size  \
# 6426  Vázquez Acosta, Iván Alejandro; Valdespino Ram...  5.54 MB
# 6432                                    Hernández, Luis  3.26 MB
# 6914                 Carbajo Veramendi, Clayton Erikson  3.26 MB
# 6922                   Molina Izarra, Vanessa Alejandra   3.1 MB
# 6925                                       Lemus, Jorge   4.7 MB
#
#                                  thesis_link  \
# 6426  http://saber.ucv.ve/handle/10872/19645
# ...

# %%
franky_thesis['thesis_year'] = pd.to_datetime(franky_thesis['thesis_year'])
franky_thesis
# Out:
#       index thesis_year                                       thesis_title  \
# 6426   7509  2019-02-26  Desarrollo de un sistema de gestión de proceso...
# 6432   7514  2019-03-06  Desarrollo de una solución de inteligencia de ...
# 6914   8039  2020-01-14  Desarrollo de modelo de arquitectura orientada...
# 6922   8035  2020-01-14  desarrollo de una solución de inteligencia de ...
# 6925   8038  2020-01-14  Desarrollo de una solución de inteligencia de ...
#
#                                           thesis_author     size  \
# 6426  Vázquez Acosta, Iván Alejandro; Valdespino Ram...  5.54 MB
# 6432                                    Hernández, Luis  3.26 MB
# 6914                 Carbajo Veramendi, Clayton Erikson  3.26 MB
# 6922                   Molina Izarra, Vanessa Alejandra   3.1 MB
# 6925                                       Lemus, Jorge   4.7 MB
#
#                                  thesis_link  \
# 6426  http://saber.ucv.ve/handle/10872/19645
# ...

# %%
franky_thesis.to_csv("data/franky_thesis.csv")

# %%
mairene_thesis = df_tutor[df_tutor["thesis_tutor"]=="Mairene ColinaCaracas"].tail(5)
df_t = mairene_thesis
df_t
# Out:
#       index  thesis_year                                       thesis_title  \
# 4313   5141   8-Mar-2017  Análisis del producto interno bruto venezolano...
# 4489   5306  20-Mar-2017  Análisis de las variaciones porcentuales del Í...
# 6474   7560  10-May-2019  Modelos ARIMA para la agrupación de palabras c...
# 6475   7561  10-May-2019  Aplicación de estadística multivariada para ca...
# 6514   7480   6-Feb-2019  Um modelo de demanda para el servicio google a...
#
#                     thesis_author       size  \
# 4313            Solórzano, Manuel     5.7 MB
# 4489      Sleiman el Zakhem, Rita     2.8 MB
# 6474  Fernández, Yoselin Arvelaiz    1.12 MB
# 6475       Castillo, José Antonio    1.94 MB
# 6514            Rodríguez, Carlos  980.32 kB
#
#                                  thesis_link  \
# 4313  http://saber.ucv.ve/handle/10872/14996
# 4489  http://saber.ucv.ve/handle/10872/15223
# 6474  http://saber.ucv.ve/handle/10872/19732
# 6475  http://saber.ucv.ve/handle/10872/19733
# ...

# %%
df_t["thesis_tutor"] = mairene_thesis["thesis_tutor"].replace('Mairene ColinaCaracas', 'Mairene Colina')
df_t
# Out:
#       index  thesis_year                                       thesis_title  \
# 4313   5141   8-Mar-2017  Análisis del producto interno bruto venezolano...
# 4489   5306  20-Mar-2017  Análisis de las variaciones porcentuales del Í...
# 6474   7560  10-May-2019  Modelos ARIMA para la agrupación de palabras c...
# 6475   7561  10-May-2019  Aplicación de estadística multivariada para ca...
# 6514   7480   6-Feb-2019  Um modelo de demanda para el servicio google a...
#
#                     thesis_author       size  \
# 4313            Solórzano, Manuel     5.7 MB
# 4489      Sleiman el Zakhem, Rita     2.8 MB
# 6474  Fernández, Yoselin Arvelaiz    1.12 MB
# 6475       Castillo, José Antonio    1.94 MB
# 6514            Rodríguez, Carlos  980.32 kB
#
#                                  thesis_link  \
# 4313  http://saber.ucv.ve/handle/10872/14996
# 4489  http://saber.ucv.ve/handle/10872/15223
# 6474  http://saber.ucv.ve/handle/10872/19732
# 6475  http://saber.ucv.ve/handle/10872/19733
# ...

# %%
df_t['thesis_year'] = pd.to_datetime(df_t['thesis_year'])
df_t
# Out:
#       index thesis_year                                       thesis_title  \
# 4313   5141  2017-03-08  Análisis del producto interno bruto venezolano...
# 4489   5306  2017-03-20  Análisis de las variaciones porcentuales del Í...
# 6474   7560  2019-05-10  Modelos ARIMA para la agrupación de palabras c...
# 6475   7561  2019-05-10  Aplicación de estadística multivariada para ca...
# 6514   7480  2019-02-06  Um modelo de demanda para el servicio google a...
#
#                     thesis_author       size  \
# 4313            Solórzano, Manuel     5.7 MB
# 4489      Sleiman el Zakhem, Rita     2.8 MB
# 6474  Fernández, Yoselin Arvelaiz    1.12 MB
# 6475       Castillo, José Antonio    1.94 MB
# 6514            Rodríguez, Carlos  980.32 kB
#
#                                  thesis_link  \
# 4313  http://saber.ucv.ve/handle/10872/14996
# 4489  http://saber.ucv.ve/handle/10872/15223
# 6474  http://saber.ucv.ve/handle/10872/19732
# 6475  http://saber.ucv.ve/handle/10872/19733
# ...

# %%
df_t.to_csv("data/mairene_thesis.csv")
