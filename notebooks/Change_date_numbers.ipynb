# %%
import pandas as pd
import numpy as np

df = pd.read_csv("data/thesis_comp_ingelec_quimica_head.csv")
df
# Out:
#     index  thesis_year                                       thesis_title  \
# 0      59   3-Jun-2011  Análisis del comportamiento de mezclas de PP c...
# 1    1610  18-Feb-2013  Caracterización y preparación de parafinas par...
# 2    1660  27-Feb-2013  Influencia del soporte de la reacción de hidro...
# 3    3095  23-Apr-2015  Síntesis y caracterízación de nuevos materiale...
# 4    3084  22-Apr-2015  Aislamiento y caracterización de los principio...
# ..    ...          ...                                                ...
# 85   5633  18-Apr-2017  Prototipo de un archivo de documentos digitale...
# 86   5728  25-May-2017  Diseño y desarrollo de un módulo de comunicaci...
# 87   5727  25-May-2017  Gestor de objetos de aprendizaje de contenidos...
# 88   5725  25-May-2017  Implantación de una plataforma de software col...
# 89   5726  25-May-2017  Implementación de un sistema de recomendación ...
#
#                                thesis_author     size  \
# ...

# %%
df['thesis_year'] = pd.to_datetime(df['thesis_year'])
df
# Out:
#     index thesis_year                                       thesis_title  \
# 0      59  2011-06-03  Análisis del comportamiento de mezclas de PP c...
# 1    1610  2013-02-18  Caracterización y preparación de parafinas par...
# 2    1660  2013-02-27  Influencia del soporte de la reacción de hidro...
# 3    3095  2015-04-23  Síntesis y caracterízación de nuevos materiale...
# 4    3084  2015-04-22  Aislamiento y caracterización de los principio...
# ..    ...         ...                                                ...
# 85   5633  2017-04-18  Prototipo de un archivo de documentos digitale...
# 86   5728  2017-05-25  Diseño y desarrollo de un módulo de comunicaci...
# 87   5727  2017-05-25  Gestor de objetos de aprendizaje de contenidos...
# 88   5725  2017-05-25  Implantación de una plataforma de software col...
# 89   5726  2017-05-25  Implementación de un sistema de recomendación ...
#
#                                thesis_author     size  \
# ...

# %%
df.to_csv("data/thesis_comp_ingelec_quimica_date_head.csv")
