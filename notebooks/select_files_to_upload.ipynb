# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data/thesis_computacion_only.csv")
df
# Out:
#      Unnamed: 0  index  thesis_year  \
# 0             8   5567  30-Mar-2017
# 1            25   5541  29-Mar-2017
# 2            28   5576  30-Mar-2017
# 3            30   5603   4-Apr-2017
# 4            31   5602   4-Apr-2017
# ..          ...    ...          ...
# 519        7133   2893   4-Dec-2014
# 520        7134   2892   4-Dec-2014
# 521        7135   2918  10-Dec-2014
# 522        7136   2920  10-Dec-2014
# 523        7152   2921  10-Dec-2014
#
#                                           thesis_title  \
# 0    Aplicación para la Gestión de Proyectos en Amb...
# 1    Generación procedimental de contenido en un vi...
# 2    Diseño y desarrollo de una aplicación móvil pa...
# 3    Sistema para la gestión de censos, encuestas y...
# 4    Modelo de sistema de gestión y monitoreo para ...
# ..                                                 ...
# 519  Desarrollo del Proceso de Gestión Empresarial ...
# 520  Sistema de información para el manejo de corre...
# ...

# %%
all_files_index = [5567, 5541, 5496, 5501, 5538, 5576, 5577, 5583, 5589, ]
