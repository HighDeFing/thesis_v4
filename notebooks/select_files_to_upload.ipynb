# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data/thesis_computacion_only.csv")
df
# Out:
#      index  thesis_year                                       thesis_title  \
# 0      898   9-Jul-2012  Desarrollo de una aplicación ambiente WEB para...
# 1      899   9-Jul-2012  Técnica para la Migración de Software basada e...
# 2     4243  19-Feb-2016  Desarrollo de una aplicación móvil para videol...
# 3     4244  19-Feb-2016  Desarrollo del módulo "trabajos académicos" de...
# 4     4245  19-Feb-2016  Sistema de inteligencia de negocio para la obt...
# ..     ...          ...                                                ...
# 532   8051  14-Jan-2020  Calidad perceptual en imágenes en escala de gr...
# 533   8062  23-Jan-2020  Desarrollo de una aplicación Web para la admin...
# 534   8063  23-Jan-2020  Desarrollo de un sistema Web para la gestión, ...
# 535   8064  23-Jan-2020  Desarrollo de una aplicación basada en la tecn...
# 536   8061  23-Jan-2020  Automatización de los procesos internos de la ...
#
#                                          thesis_author     size  \
# ...

# %%
df = pd.read_csv('./data/thesis_tutor_7078_clean_v2.csv')
df
# Out:
#       index  thesis_year                                       thesis_title  \
# 0         1         2009  Estudio de sobretensiones por maniobra debido ...
# 1        95  20-Jun-2011  Estudio de la influencia de las condiciones de...
# 2        22  31-May-2011  Efecto de los rayos gamma (g) sobre el comport...
# 3        24  31-May-2011  Determinación de registros pseudo sónicos a pa...
# 4        25  31-May-2011  Propuesta de un sistema de administración de i...
# ...     ...          ...                                                ...
# 7073   8190  12-Nov-2020  Magnitud y estructura del abastecimiento exter...
# 7074   8192  12-Nov-2020  Evaluación del Impacto de Cambios de Cobertura...
# 7075   8193  18-Nov-2020  Efecto de la sombra sobre la concentración de ...
# 7076   8196  18-Nov-2020  Evaluación del comportamiento ecofisiológico d...
# 7077   8211  12-Mar-2021  La industria musical surcoreana, recepción y a...
#
# ...

# %%
all_files_index = [5567, 5541, 5496, 5501, 5538, 5576, 5577, 5583, 5589, 5590, 5592, 5593, 5594, 5595, 5598, 5599, 5600, 
                  5601, 5602, 5603, 5725, 5726, 5727, 5728, 5628, 5629, 5630, 5631, 5341, 5633]

# %%
len(all_files_index) #todo bien 30 files
# Out:
# 30

# %%
#df = df.iloc[: , 1:] #delete first column
df
# Out:
#       index  thesis_year                                       thesis_title  \
# 0         1         2009  Estudio de sobretensiones por maniobra debido ...
# 1        95  20-Jun-2011  Estudio de la influencia de las condiciones de...
# 2        22  31-May-2011  Efecto de los rayos gamma (g) sobre el comport...
# 3        24  31-May-2011  Determinación de registros pseudo sónicos a pa...
# 4        25  31-May-2011  Propuesta de un sistema de administración de i...
# ...     ...          ...                                                ...
# 7073   8190  12-Nov-2020  Magnitud y estructura del abastecimiento exter...
# 7074   8192  12-Nov-2020  Evaluación del Impacto de Cambios de Cobertura...
# 7075   8193  18-Nov-2020  Efecto de la sombra sobre la concentración de ...
# 7076   8196  18-Nov-2020  Evaluación del comportamiento ecofisiológico d...
# 7077   8211  12-Mar-2021  La industria musical surcoreana, recepción y a...
#
# ...

# %%
seletec_df = df[df['index'].isin(all_files_index)]
seletec_df
# Out:
#       index  thesis_year                                       thesis_title  \
# 4505   5341  22-Mar-2017  Modelo de Gestión de Información, de un Instit...
# 4657   5496  28-Mar-2017  Sistema de información para el cálculo de la b...
# 4663   5501  28-Mar-2017  Diseño e implementación de un sistema para la ...
# 4699   5538  29-Mar-2017  Implementación de los módulos de adquisición y...
# 4703   5541  29-Mar-2017  Generación procedimental de contenido en un vi...
# 4719   5567  30-Mar-2017  Aplicación para la Gestión de Proyectos en Amb...
# 4727   5576  30-Mar-2017  Diseño y desarrollo de una aplicación móvil pa...
# 4729   5603   4-Apr-2017  Sistema para la gestión de censos, encuestas y...
# 4733   5583   3-Apr-2017  Desarrollo de un sistema de información geográ...
# 4739   5589   3-Apr-2017  Desarrollo de un sistema de alquiler de cancha...
# 4740   5577  30-Mar-2017  Sistema de información para la automatización ...
# ...

# %%
len(seletec_df)
# Out:
# 30

# %%
seletec_df.to_csv("data/thesis_30_computacion.csv", index=False)

# %% [markdown]
# ## Clasificar las celdas
#
# A partir de aqui se tomaran 30 tesis de Ingenieria Electrica, Computacion y Quimica. Estas tesis seran las que se utilizaran para tener las pruebas en tiempo real.
#
# Las tesis de computacion fueron las unicas utilizadas para realizar el entrenamiento y validacion de los modelos, se incluyeron dos carreras mas por limitaciones pero para hacer probar que el clasificador de carreras funciona.
#
# La idea es tener imagenes de las pruebas para mostrar la vista final al usuario.

# %%
df = pd.read_csv('./data/thesis_tutor_7078_clean_v2.csv')
df
# Out:
#       index  thesis_year                                       thesis_title  \
# 0         1         2009  Estudio de sobretensiones por maniobra debido ...
# 1        95  20-Jun-2011  Estudio de la influencia de las condiciones de...
# 2        22  31-May-2011  Efecto de los rayos gamma (g) sobre el comport...
# 3        24  31-May-2011  Determinación de registros pseudo sónicos a pa...
# 4        25  31-May-2011  Propuesta de un sistema de administración de i...
# ...     ...          ...                                                ...
# 7073   8190  12-Nov-2020  Magnitud y estructura del abastecimiento exter...
# 7074   8192  12-Nov-2020  Evaluación del Impacto de Cambios de Cobertura...
# 7075   8193  18-Nov-2020  Efecto de la sombra sobre la concentración de ...
# 7076   8196  18-Nov-2020  Evaluación del comportamiento ecofisiológico d...
# 7077   8211  12-Mar-2021  La industria musical surcoreana, recepción y a...
#
# ...

# %% [markdown]
# ## Escuela de Computación

# %%
df_comp = df[df['school_complex'] == "Escuela de Computación"]
df_comp
# Out:
#       index  thesis_year                                       thesis_title  \
# 530     898   9-Jul-2012  Desarrollo de una aplicación ambiente WEB para...
# 531     899   9-Jul-2012  Técnica para la Migración de Software basada e...
# 1168   4243  19-Feb-2016  Desarrollo de una aplicación móvil para videol...
# 1169   4244  19-Feb-2016  Desarrollo del módulo "trabajos académicos" de...
# 1170   4245  19-Feb-2016  Sistema de inteligencia de negocio para la obt...
# ...     ...          ...                                                ...
# 6938   8051  14-Jan-2020  Calidad perceptual en imágenes en escala de gr...
# 6946   8062  23-Jan-2020  Desarrollo de una aplicación Web para la admin...
# 6947   8063  23-Jan-2020  Desarrollo de un sistema Web para la gestión, ...
# 6948   8064  23-Jan-2020  Desarrollo de una aplicación basada en la tecn...
# 6957   8061  23-Jan-2020  Automatización de los procesos internos de la ...
#
# ...

# %%
#df_comp_30 = df_comp.sample(n = 30, random_state = 2)
#df_comp_30
df_comp
# Out:
#       index  thesis_year                                       thesis_title  \
# 530     898   9-Jul-2012  Desarrollo de una aplicación ambiente WEB para...
# 531     899   9-Jul-2012  Técnica para la Migración de Software basada e...
# 1168   4243  19-Feb-2016  Desarrollo de una aplicación móvil para videol...
# 1169   4244  19-Feb-2016  Desarrollo del módulo "trabajos académicos" de...
# 1170   4245  19-Feb-2016  Sistema de inteligencia de negocio para la obt...
# ...     ...          ...                                                ...
# 6938   8051  14-Jan-2020  Calidad perceptual en imágenes en escala de gr...
# 6946   8062  23-Jan-2020  Desarrollo de una aplicación Web para la admin...
# 6947   8063  23-Jan-2020  Desarrollo de un sistema Web para la gestión, ...
# 6948   8064  23-Jan-2020  Desarrollo de una aplicación basada en la tecn...
# 6957   8061  23-Jan-2020  Automatización de los procesos internos de la ...
#
# ...

# %%
len(df_comp)
# Out:
# 537

# %%
all_files_index = [5567, 5541, 5496, 5501, 5538, 5576, 5577, 5583, 5589, 5590, 5592, 5593, 5594, 5595, 5598, 5599, 5600, 
                  5601, 5602, 5603, 5725, 5726, 5727, 5728, 5628, 5629, 5630, 5631, 5341, 5633]

# %%
df_comp_30 = df_comp[df_comp['index'].isin(all_files_index)]
df_comp_30
# Out:
#       index  thesis_year                                       thesis_title  \
# 4505   5341  22-Mar-2017  Modelo de Gestión de Información, de un Instit...
# 4657   5496  28-Mar-2017  Sistema de información para el cálculo de la b...
# 4663   5501  28-Mar-2017  Diseño e implementación de un sistema para la ...
# 4699   5538  29-Mar-2017  Implementación de los módulos de adquisición y...
# 4703   5541  29-Mar-2017  Generación procedimental de contenido en un vi...
# 4719   5567  30-Mar-2017  Aplicación para la Gestión de Proyectos en Amb...
# 4727   5576  30-Mar-2017  Diseño y desarrollo de una aplicación móvil pa...
# 4729   5603   4-Apr-2017  Sistema para la gestión de censos, encuestas y...
# 4733   5583   3-Apr-2017  Desarrollo de un sistema de información geográ...
# 4739   5589   3-Apr-2017  Desarrollo de un sistema de alquiler de cancha...
# 4740   5577  30-Mar-2017  Sistema de información para la automatización ...
# ...

# %%
len(df_comp_30)
# Out:
# 30

# %% [markdown]
# ## Escuela de Química

# %%
df_quim = df[df['school_complex'] == "Escuela de Química"]
df_quim
# Out:
#       index  thesis_year                                       thesis_title  \
# 39       59   3-Jun-2011  Análisis del comportamiento de mezclas de PP c...
# 1204   1610  18-Feb-2013  Caracterización y preparación de parafinas par...
# 1305   1660  27-Feb-2013  Influencia del soporte de la reacción de hidro...
# 1915   3095  23-Apr-2015  Síntesis y caracterízación de nuevos materiale...
# 1916   3084  22-Apr-2015  Aislamiento y caracterización de los principio...
# ...     ...          ...                                                ...
# 6951   8068  23-Jan-2020  Desorción de gases asociados a las fracciones ...
# 6952   8069  23-Jan-2020  Relación entre la viscosidad y el nivel de bio...
# 6953   8070  23-Jan-2020  Influencia del pH, conductividad, contenido de...
# 6954   8071  23-Jan-2020  Influencia del pH, conductividad, contenido de...
# 6967   8089  29-Jan-2020  Caracterización de los metabolitos secundarios...
#
#                           thesis_author     size  \
# ...

# %%
df_quim_30 = df_quim.head(30)
df_quim_30
# Out:
#       index  thesis_year                                       thesis_title  \
# 39       59   3-Jun-2011  Análisis del comportamiento de mezclas de PP c...
# 1204   1610  18-Feb-2013  Caracterización y preparación de parafinas par...
# 1305   1660  27-Feb-2013  Influencia del soporte de la reacción de hidro...
# 1915   3095  23-Apr-2015  Síntesis y caracterízación de nuevos materiale...
# 1916   3084  22-Apr-2015  Aislamiento y caracterización de los principio...
# 1922   3090  23-Apr-2015  Evaluación del contenido de metales pesados en...
# 1935   3074  20-Apr-2015  Determinación de mercurio en los sedimientos s...
# 1997   3082  20-Apr-2015  Desarrollo de un método rápido mediante cromat...
# 2177   2762   3-Nov-2014  Polarizabilidad e hiperpolarizabilidades estát...
# 2188   2707  27-Oct-2014  Caracterización de querógenos de la cuenca occ...
# 2217   3083  20-Apr-2015  Diseño de una metodología de determinación de ...
# ...

# %%
len(df_quim_30)
# Out:
# 30

# %% [markdown]
# ## Escuela de Ingeniería Eléctrica

# %%
df_ingelec = df[df['school_complex'] == "Escuela de Ingeniería Eléctrica"] 
df_ingelec
# Out:
#       index  thesis_year                                       thesis_title  \
# 0         1         2009  Estudio de sobretensiones por maniobra debido ...
# 223     512   7-Nov-2011  Desarrollo de un sistema de control para mante...
# 235     513   7-Nov-2011  Estudio de factibilidad técnica y económica pa...
# 237     514   7-Nov-2011  Estudio de planificación a corto plazo de las ...
# 238     515   7-Nov-2011  Análisis de la factibilidad técnica para manej...
# ...     ...          ...                                                ...
# 7037   8166   2-Nov-2020  Evaluación de la sustentabilidad del edificio ...
# 7067   8116  30-Sep-2020  Implementación del Flickermetro de la Norma IE...
# 7068   8117  30-Sep-2020  Rehabilitación de una subestación móvil 115/13...
# 7069   8118  30-Sep-2020  Desarrollo de una herramienta computarizada, p...
# 7070   8119  30-Sep-2020  Automatización de una máquina de impresión tip...
#
# ...

# %%
#df_ingelec_30 = df_ingelec.sample(n = 30, random_state = 2)
df_ingelec_30 = df_ingelec.head(30)
df_ingelec_30
# Out:
#      index  thesis_year                                       thesis_title  \
# 0        1         2009  Estudio de sobretensiones por maniobra debido ...
# 223    512   7-Nov-2011  Desarrollo de un sistema de control para mante...
# 235    513   7-Nov-2011  Estudio de factibilidad técnica y económica pa...
# 237    514   7-Nov-2011  Estudio de planificación a corto plazo de las ...
# 238    515   7-Nov-2011  Análisis de la factibilidad técnica para manej...
# 239    516   7-Nov-2011  Elaboración de una propuesta de protocolo de s...
# 240    517   7-Nov-2011  Evaluación de la calidad del servicio eléctric...
# 241    518   7-Nov-2011  Diseño de la plataforma para transmisión de se...
# 242    519   7-Nov-2011  Implementación y desarrollo de un sistema de m...
# 243    520   7-Nov-2011  Ingeniería básicas de subestación eléctrica 34...
# 244    521   7-Nov-2011  Estudio de factibilidad técnico-económica para...
# ...

# %%
len(df_ingelec_30)
# Out:
# 30

# %% [markdown]
# ## Merge

# %%
df_concat = pd.concat([df_quim_30, df_ingelec_30, df_comp_30], ignore_index=True)
df_concat
# Out:
#     index  thesis_year                                       thesis_title  \
# 0      59   3-Jun-2011  Análisis del comportamiento de mezclas de PP c...
# 1    1610  18-Feb-2013  Caracterización y preparación de parafinas par...
# 2    1660  27-Feb-2013  Influencia del soporte de la reacción de hidro...
# 3    3095  23-Apr-2015  Síntesis y caracterízación de nuevos materiale...
# 4    3084  22-Apr-2015  Aislamiento y caracterización de los principio...
# ..    ...          ...                                                ...
# 85   5633  18-Apr-2017  Prototipo de un archivo de documentos digitale...
# 86   5728  25-May-2017  Diseño y desarrollo de un módulo de comunicaci...
# 87   5727  25-May-2017  Gestor de objetos de aprendizaje de contenidos...
# 88   5725  25-May-2017  Implantación de una plataforma de software col...
# 89   5726  25-May-2017  Implementación de un sistema de recomendación ...
#
#                                thesis_author     size  \
# ...

# %%
len(df_concat)
# Out:
# 90

# %%
df_concat.to_csv("data/thesis_comp_ingelec_quimica_head.csv", index=False)
